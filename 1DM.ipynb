# %%
# Handwritten Digit Recognition using MNIST Dataset
# Google Colab Compatible

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize data (0-255 -> 0-1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# Build Neural Network Model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train Model
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_data=(x_test, y_test)
)

# Evaluate Model
test_loss, test_acc = model.evaluate(x_test, y_test)

print("\nTest Accuracy:", test_acc)

# Predict Sample Digit
prediction = model.predict(x_test)

# Display Sample Image
plt.imshow(x_test[2], cmap='gray')
plt.title(f"Actual Digit: {y_test[2]}")
plt.show()

# Predicted Digit
predicted_digit = np.argmax(prediction[2])
print("Predicted Digit:", predicted_digit)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9295 - loss: 0.2389 - val_accuracy: 0.9673 - val_loss: 0.1111
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9698 - loss: 0.1001 - val_accuracy: 0.9705 - val_loss: 0.0901
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9783 - loss: 0.0697 - val_accuracy: 0.9727 - val_loss: 0.0843
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9839 - loss: 0.0512 - val_accuracy: 0.9763 - val_loss: 0.0812
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9865 - loss: 0.0427 - val_accuracy: 0.9741 - val_loss: 0.0812
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9741 - loss: 0.0812
#
# Test Accuracy: 0.9740999937057495
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Predicted Digit: 1
